# %% [markdown]
# <a href="https://colab.research.google.com/github/EnjelinaJuwita/PembelajaranMesin/blob/main/Tugas%201%20Pembelajaran%20Mesin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset = '/content/segmentation data.csv'

# %%
data = pd.read_csv(dataset)

# %%
data
# Out:
#              ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0     100000001    0               0   67          2  124670           1
# 1     100000002    1               1   22          1  150773           1
# 2     100000003    0               0   49          1   89210           0
# 3     100000004    0               0   45          1  171565           1
# 4     100000005    0               0   53          1  149031           1
# ...         ...  ...             ...  ...        ...     ...         ...
# 1995  100001996    1               0   47          1  123525           0
# 1996  100001997    1               1   27          1  117744           1
# 1997  100001998    0               0   31          0   86400           0
# 1998  100001999    1               1   24          1   97968           0
# 1999  100002000    0               0   25          0   68416           0
#
#       Settlement size
# 0                   2
# 1                   2
# ...

# %%
data.head()
# Out:
#           ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0  100000001    0               0   67          2  124670           1
# 1  100000002    1               1   22          1  150773           1
# 2  100000003    0               0   49          1   89210           0
# 3  100000004    0               0   45          1  171565           1
# 4  100000005    0               0   53          1  149031           1
#
#    Settlement size
# 0                2
# 1                2
# 2                0
# 3                1
# 4                1

# %%
print(data.dtypes)
# Out:
# ID                 int64
# Sex                int64
# Marital status     int64
# Age                int64
# Education          int64
# Income             int64
# Occupation         int64
# Settlement size    int64
# dtype: object

# %%
datanoid = data.drop(data.columns[4], axis=1)

# %%
datanoid
# Out:
#              ID  Sex  Marital status  Age  Income  Occupation  Settlement size
# 0     100000001    0               0   67  124670           1                2
# 1     100000002    1               1   22  150773           1                2
# 2     100000003    0               0   49   89210           0                0
# 3     100000004    0               0   45  171565           1                1
# 4     100000005    0               0   53  149031           1                1
# ...         ...  ...             ...  ...     ...         ...              ...
# 1995  100001996    1               0   47  123525           0                0
# 1996  100001997    1               1   27  117744           1                0
# 1997  100001998    0               0   31   86400           0                0
# 1998  100001999    1               1   24   97968           0                0
# 1999  100002000    0               0   25   68416           0                0
#
# [2000 rows x 7 columns]

# %%
data.describe()
# Out:
#                  ID          Sex  Marital status          Age   Education  \
# count  2.000000e+03  2000.000000     2000.000000  2000.000000  2000.00000
# mean   1.000010e+08     0.457000        0.496500    35.909000     1.03800
# std    5.774946e+02     0.498272        0.500113    11.719402     0.59978
# min    1.000000e+08     0.000000        0.000000    18.000000     0.00000
# 25%    1.000005e+08     0.000000        0.000000    27.000000     1.00000
# 50%    1.000010e+08     0.000000        0.000000    33.000000     1.00000
# 75%    1.000015e+08     1.000000        1.000000    42.000000     1.00000
# max    1.000020e+08     1.000000        1.000000    76.000000     3.00000
#
#               Income   Occupation  Settlement size
# count    2000.000000  2000.000000      2000.000000
# mean   120954.419000     0.810500         0.739000
# std     38108.824679     0.638587         0.812533
# min     35832.000000     0.000000         0.000000
# ...

# %%
data.loc[:,"Age":].corr()
# Out:
#                       Age  Education    Income  Occupation  Settlement size
# Age              1.000000   0.654605  0.340610    0.108388         0.119751
# Education        0.654605   1.000000  0.233459    0.064524         0.034732
# Income           0.340610   0.233459  1.000000    0.680357         0.490881
# Occupation       0.108388   0.064524  0.680357    1.000000         0.571795
# Settlement size  0.119751   0.034732  0.490881    0.571795         1.000000

# %%
# @title Age vs Education

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='Age', y='Education', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-ac1c3a5e-383d-4c54-8bce-ec9dff3856c6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ac1c3a5e-383d-4c54-8bce-ec9dff3856c6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "segmentation"
# Out:
# ...
# ref                                                             title                                           size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  ---------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# vetrirah/customer                                               Customer Segmentation                          105KB  2020-08-28 11:19:39          14372        145  1.0
# mateuszbuda/lgg-mri-segmentation                                Brain MRI segmentation                         714MB  2019-05-02 21:32:45          53739        794  0.875
# vjchoudhary7/customer-segmentation-tutorial-in-python           Mall Customer Segmentation Data                  2KB  2018-08-11 07:23:02         158081       1594  0.88235295
# ...

# %%
# !kaggle datasets download vetrirah/customer
# Out:
# ...
#   0% 0.00/105k [00:00<?, ?B/s]
# 100% 105k/105k [00:00<00:00, 75.0MB/s]

# %%
# !unzip /content/customer.zip
# Out:
# Archive:  /content/customer.zip
#   inflating: Test.csv
#   inflating: Train.csv
#   inflating: sample_submission.csv

# %%
pd.read_csv('/content/Test.csv')
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     458989  Female          Yes   36       Yes       Engineer
# 1     458994    Male          Yes   37       Yes     Healthcare
# 2     458996  Female          Yes   69        No            NaN
# 3     459000    Male          Yes   59        No      Executive
# 4     459001  Female           No   19        No      Marketing
# ...      ...     ...          ...  ...       ...            ...
# 2622  467954    Male           No   29        No     Healthcare
# 2623  467958  Female           No   35       Yes         Doctor
# 2624  467960  Female           No   53       Yes  Entertainment
# 2625  467961    Male          Yes   47       Yes      Executive
# 2626  467968  Female           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1
# 0                 0.0            Low          1.0  Cat_6
# 1                 8.0        Average          4.0  Cat_6
# ...

# %%
pd.read_csv('/content/Train.csv')
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No            NaN
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %%
pd.read_csv('/content/sample_submission.csv')
# Out:
#           ID Segmentation
# 0     458989            A
# 1     458994            A
# 2     458996            A
# 3     459000            A
# 4     459001            A
# ...      ...          ...
# 2622  467954            A
# 2623  467958            A
# 2624  467960            A
# 2625  467961            A
# 2626  467968            A
#
# [2627 rows x 2 columns]
